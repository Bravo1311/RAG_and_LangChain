# %%
import os
from dotenv import load_dotenv
load_dotenv()

from smolVLM import SmolVLM

# os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")  
# os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")  
# os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       3 load_dotenv()
#       4
#       5 from smolVLM import SmolVLM
#       6
# ----> 7 os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
#       8 os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
#       9 os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
#
# File <frozen os>:690, in _Environ.__setitem__(self, key, value)
#     688 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:764, in _createenviron.<locals>.encode(value)
#     762 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType

# %%
from langchain.chat_models import init_chat_model

# model = init_chat_model("gpt-4.1")
model = SmolVLM()
model
# model.invoke("Hello, how are you?")
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x7e0b5729f8f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7e0b5729fad0>, root_client=<openai.OpenAI object at 0x7e0b57307fb0>, root_async_client=<openai.AsyncOpenAI object at 0x7e0b5729f890>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=Secret
# ...

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
# response = model.stream("Can you handle image analysis in the context of identifying zones where gnss could be degraded due to multipath?")

for chunk in model.stream("Can you handle image analysis in the context of identifying zones where gnss could be degraded due to multipath?"):
    print(chunk.text, end="|", flush=True)
# Out:
# Yes, I can handle| image analysis in the context of identifying zones where GNSS (Global Navigation Satellite System) could be| degraded due to multipath.
#
# Here's how I can approach this and what kind of information I would need from you:
#
# **Understanding Multipath and its Visual Signatures**
#
# Multipath occurs when GNSS signals bounce off nearby| objects (buildings, trees, vehicles, terrain) before reaching the receiver. This creates multiple signal paths, leading to:
#
# *   **Signal Reflection:** The reflected signals arrive at the receiver with a delay and potentially different phase and amplitude compared to the direct| signal.
# *   **Interference:** These multiple signals interfere with each other, causing errors in the receiver's position and timing calculations.
# *   **"Ghost" Signals:** The receiver might lock onto a reflected signal instead of the direct signal, leading| to significant position jumps or inaccuracies.
#
# ...
